# %% [markdown]
# Hardware refers to the physical components of a computer system that you can touch and see. Software, on the other hand, is a set of instructions, data, or programs used to operate computers and execute specific tasks.
#
# Here's an example of each:
#
# Hardware: A computer monitor (the physical screen you look at).
# Software: A web browser like Google Chrome (the program that allows you to surf the internet).
